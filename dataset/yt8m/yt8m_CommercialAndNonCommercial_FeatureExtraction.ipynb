# %%
# Import important libraries 
import tensorflow as tf
import pandas as pd
from IPython.display import YouTubeVideo
import os
import pickle
import random

# %%
records_path = "./2/frame/train"

# %%
with open('filtered_rgb.pkl', 'rb') as f:
    loaded_rgb = pickle.load(f)

with open('filtered_audio.pkl', 'rb') as f:
    loaded_audio = pickle.load(f)

print('Filtered data features loaded successfully.')
# Out:
# Filtered data features loaded successfully.

# %%
with open('non_Commercial_Rgb.pkl', 'rb') as f:
    non_Commercial_Rgb = pickle.load(f)

with open('non_Commercial_Audio.pkl', 'rb') as f:
    non_Commercial_Audio = pickle.load(f)
 
print('Non-Commercial data features loaded successfully.')
# Out:
# Non-Commercial data features loaded successfully.

# %%
# Verifying the loading of features
print(f'Number of TV Advertisement RGB feature lists loaded: {len(loaded_rgb)}')
print(f'Number of TV Advertisement audio feature lists loaded: {len(loaded_audio)}')
# Out:
# Number of TV Advertisement RGB feature lists loaded: 2358
# Number of TV Advertisement audio feature lists loaded: 2358

# %%
# Verifying the loading of features
print(f'Number of Non-TV RGB feature lists loaded: {len(non_Commercial_Rgb)}')
print(f'Number of Non-Tv audio feature lists loaded: {len(non_Commercial_Audio)}')
# Out:
# Number of Non-TV RGB feature lists loaded: 1000
# Number of Non-Tv audio feature lists loaded: 1000

# %%
filtered_vid_ids = []           # This array stores the video IDs of Television Advertisement label extracted from the TFRecord file.
filtered_labels = []            # This array stores the label_ids associated with Television Advertisment label_id(315). The label ids are mapped to label names through vocabulary.csv which is discussed later.
filtered_rgb = loaded_rgb       # This array stores the RGB features of Television Advertisement label.
filtered_audio = loaded_audio   # This array stores the audio features of Television Advertisement label.

non_filtered_vid_ids = []       # This array stores the video IDs without the Television Advertisement label extracted from the TFRecord file.
non_filtered_labels = []        # This array stores the label_ids associated without Television Advertisment label_id(315). The label ids are mapped to label names through vocabulary.csv which is discussed later.
non_filtered_rgb = []           # This array stores the RGB features without the Television Advertisement label.
non_filtered_audio = []         # This array stores the audio features without the Television Advertisement label.

# %%
def decode_quantized_features(features):
    return tf.io.decode_raw(features, tf.uint8)

# %%
# List all .tfrecord files in the directory
tfrecord_files = [os.path.join(records_path, f) for f in os.listdir(records_path) if f.endswith('.tfrecord')]

# The specific labels for the non-filtered lists
specific_labels = {12, 329, 282, 52, 67, 92, 118, 653}

# %%
# Iterate over each .tfrecord file
counter = 0
for tfrecord_file in tfrecord_files:
    print(f'counter {counter}')
    counter+=1
    print(f'Processing file: {tfrecord_file}')
    # Iterate over each tfrecord in the TFRecord file
    try:
        for record in tf.compat.v1.python_io.tf_record_iterator(tfrecord_file):
            try:
                # Parse the SequenceExample from the binary record data
                seq_example = tf.train.SequenceExample.FromString(record)

                # Extract the video_id and labels
                vid_id = seq_example.context.feature['id'].bytes_list.value[0].decode('UTF-8')
                labels_list = seq_example.context.feature['labels'].int64_list.value

                # Check if the label ID 315 is in the labels list (label id 315 corresponds to Television Advertisement)
                if 315 in labels_list:
                    # Append video ID and labels to the filtered lists
                    filtered_vid_ids.append(vid_id)
                    filtered_labels.append(labels_list)

                    # Lists to store frame-level and audio-level features
                    rgb_features = []
                    audio_features = []

                    # Iterate over each frame-level feature pair (RGB and audio) in the SequenceExample
                    for rgb_feature, audio_feature in zip(seq_example.feature_lists.feature_list['rgb'].feature,
                                                          seq_example.feature_lists.feature_list['audio'].feature):
                        
                        # Decode the quantized RGB features and audio features
                        decoded_rgb = decode_quantized_features(rgb_feature.bytes_list.value[0])
                        decoded_audio = decode_quantized_features(audio_feature.bytes_list.value[0])

                        rgb_features.append(decoded_rgb)
                        audio_features.append(decoded_audio)

                    # Append frame-level lists to the main filtered lists
                    filtered_rgb.append(rgb_features)
                    filtered_audio.append(audio_features)
                else:
                    # Check if the labels list contains any of the specific labels
                    if any(label in specific_labels for label in labels_list):
                        # Append video ID and labels to the non-filtered lists
                        non_filtered_vid_ids.append(vid_id)
                        non_filtered_labels.append(labels_list)

                        # Lists to store frame-level and audio-level features
                        rgb_features = []
                        audio_features = []

                        # Iterate over each frame-level feature pair (RGB and audio) in the SequenceExample
                        for rgb_feature, audio_feature in zip(seq_example.feature_lists.feature_list['rgb'].feature,
                                                              seq_example.feature_lists.feature_list['audio'].feature):
                            
                            # Decode the quantized RGB features and audio features
                            decoded_rgb = decode_quantized_features(rgb_feature.bytes_list.value[0])
                            decoded_audio = decode_quantized_features(audio_feature.bytes_list.value[0])

                            rgb_features.append(decoded_rgb)
                            audio_features.append(decoded_audio)

                        # Append frame-level lists to the main non-filtered lists
                        non_filtered_rgb.append(rgb_features)
                        non_filtered_audio.append(audio_features)

            except tf.errors.DataLossError as e:
                print(f'Skipping corrupted record in file {tfrecord_file}: {e}')
    except tf.errors.DataLossError as e:
        print(f'Skipping entire file due to corruption: {tfrecord_file}: {e}')

# At this point, the following lists contain the relevant data:
# filtered_vid_ids, filtered_labels, filtered_rgb, and filtered_audio contain data for videos with the label "Television advertisement".
# non_filtered_vid_ids, non_filtered_labels, non_filtered_rgb, and non_filtered_audio contain data for videos with the specified labels.
# Out:
# counter 0
# Processing file: ./2/frame/train/train0670.tfrecord
# WARNING:tensorflow:From /var/folders/hg/7q10m6ks77bcpykgf2nbst5h0000gn/T/ipykernel_39781/538426751.py:9: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# counter 1
# Processing file: ./2/frame/train/train2511.tfrecord
# counter 2
# Processing file: ./2/frame/train/train0417.tfrecord
# counter 3
# Processing file: ./2/frame/train/train3170.tfrecord
# counter 4
# Processing file: ./2/frame/train/train2889.tfrecord
# counter 5
# Processing file: ./2/frame/train/train3139.tfrecord
# counter 6
# Processing file: ./2/frame/train/train0002.tfrecord
# counter 7
# Processing file: ./2/frame/train/train3565.tfrecord
# counter 8
# Processing file: ./2/frame/train/train0731.tfrecord
# counter 9
# Processing file: ./2/frame/train/train0730.tfrecord
# counter 10
# Processing file: ./2/frame/train/train0922.tfrecord
# counter 11
# Processing file: ./2/frame/train/train2386.tfrecord
# counter 12
# Processing file: ./2/frame/train/train0281.tfrecord
# counter 13
# Processing file: ./2/frame/train/train3328.tfrecord
# counter 14
# Processing file: ./2/frame/train/train1327.tfrecord
# counter 15
# Processing file: ./2/frame/train/train3046.tfrecord
# counter 16
# Processing file: ./2/frame/train/train3489.tfrecord
# counter 17
# Processing file: ./2/frame/train/train0607.tfrecord
# counter 18
# Processing file: ./2/frame/train/train1001.tfrecord
# counter 19
# Processing file: ./2/frame/train/train3360.tfrecord
# counter 20
# Processing file: ./2/frame/train/train3106.tfrecord
# counter 21
# Processing file: ./2/frame/train/train2255.tfrecord
# counter 22
# Processing file: ./2/frame/train/train0134.tfrecord
# counter 23
# Processing file: ./2/frame/train/train0569.tfrecord
# counter 24
# Processing file: ./2/frame/train/train2608.tfrecord
# counter 25
# Processing file: ./2/frame/train/train0695.tfrecord
# counter 26
# Processing file: ./2/frame/train/train1093.tfrecord
# counter 27
# Processing file: ./2/frame/train/train3195.tfrecord
# counter 28
# Processing file: ./2/frame/train/train1469.tfrecord
# counter 29
# Processing file: ./2/frame/train/train0856.tfrecord
# counter 30
# Processing file: ./2/frame/train/train3132.tfrecord
# counter 31
# Processing file: ./2/frame/train/train1034.tfrecord
# counter 32
# Processing file: ./2/frame/train/train2146.tfrecord
# counter 33
# Processing file: ./2/frame/train/train0772.tfrecord
# counter 34
# Processing file: ./2/frame/train/train0773.tfrecord
# counter 35
# Processing file: ./2/frame/train/train0515.tfrecord
# counter 36
# Processing file: ./2/frame/train/train3215.tfrecord
# counter 37
# Processing file: ./2/frame/train/train0917.tfrecord
# counter 38
# Processing file: ./2/frame/train/train3286.tfrecord
# counter 39
# Processing file: ./2/frame/train/train1823.tfrecord
# counter 40
# Processing file: ./2/frame/train/train2799.tfrecord
# counter 41
# Processing file: ./2/frame/train/train1102.tfrecord
# counter 42
# Processing file: ./2/frame/train/train1739.tfrecord
# counter 43
# Processing file: ./2/frame/train/train3459.tfrecord
# counter 44
# Processing file: ./2/frame/train/train2039.tfrecord
# counter 45
# Processing file: ./2/frame/train/train1854.tfrecord
# counter 46
# Processing file: ./2/frame/train/train1771.tfrecord
# counter 47
# Processing file: ./2/frame/train/train3573.tfrecord
# counter 48
# Processing file: ./2/frame/train/train2375.tfrecord
# counter 49
# Processing file: ./2/frame/train/train0273.tfrecord
# counter 50
# Processing file: ./2/frame/train/train2620.tfrecord
# counter 51
# Processing file: ./2/frame/train/train0727.tfrecord
# counter 52
# Processing file: ./2/frame/train/train3027.tfrecord
# counter 53
# Processing file: ./2/frame/train/train0943.tfrecord
# counter 54
# Processing file: ./2/frame/train/train0508.tfrecord
# counter 55
# Processing file: ./2/frame/train/train3392.tfrecord
# counter 56
# Processing file: ./2/frame/train/train1206.tfrecord
# counter 57
# Processing file: ./2/frame/train/train2052.tfrecord
# counter 58
# Processing file: ./2/frame/train/train0155.tfrecord
# counter 59
# Processing file: ./2/frame/train/train2235.tfrecord
# counter 60
# Processing file: ./2/frame/train/train1084.tfrecord
# counter 61
# Processing file: ./2/frame/train/train0682.tfrecord
# counter 62
# Processing file: ./2/frame/train/train3111.tfrecord
# counter 63
# Processing file: ./2/frame/train/train2570.tfrecord
# counter 64
# Processing file: ./2/frame/train/train0122.tfrecord
# counter 65
# Processing file: ./2/frame/train/train0344.tfrecord
# counter 66
# Processing file: ./2/frame/train/train1725.tfrecord
# counter 67
# Processing file: ./2/frame/train/train3050.tfrecord
# counter 68
# Processing file: ./2/frame/train/train2832.tfrecord
# counter 69
# Processing file: ./2/frame/train/train2538.tfrecord
# counter 70
# Processing file: ./2/frame/train/train2058.tfrecord
# counter 71
# Processing file: ./2/frame/train/train0901.tfrecord
# counter 72
# Processing file: ./2/frame/train/train2150.tfrecord
# counter 73
# Processing file: ./2/frame/train/train0056.tfrecord
# counter 74
# Processing file: ./2/frame/train/train2151.tfrecord
# counter 75
# Processing file: ./2/frame/train/train1304.tfrecord
# counter 76
# Processing file: ./2/frame/train/train0502.tfrecord
# counter 77
# Processing file: ./2/frame/train/train3342.tfrecord
# counter 78
# Processing file: ./2/frame/train/train3684.tfrecord
# counter 79
# Processing file: ./2/frame/train/train2083.tfrecord
# counter 80
# Processing file: ./2/frame/train/train2082.tfrecord
# counter 81
# Processing file: ./2/frame/train/train0840.tfrecord
# counter 82
# Processing file: ./2/frame/train/train2946.tfrecord
# counter 83
# Processing file: ./2/frame/train/train2119.tfrecord
# counter 84
# Processing file: ./2/frame/train/train0278.tfrecord
# counter 85
# Processing file: ./2/frame/train/train3407.tfrecord
# counter 86
# Processing file: ./2/frame/train/train0160.tfrecord
# counter 87
# Processing file: ./2/frame/train/train0306.tfrecord
# counter 88
# Processing file: ./2/frame/train/train1903.tfrecord
# counter 89
# Processing file: ./2/frame/train/train1899.tfrecord
# counter 90
# Processing file: ./2/frame/train/train2308.tfrecord
# counter 91
# Processing file: ./2/frame/train/train0128.tfrecord
# counter 92
# Processing file: ./2/frame/train/train0780.tfrecord
# counter 93
# Processing file: ./2/frame/train/train2472.tfrecord
# counter 94
# Processing file: ./2/frame/train/train1871.tfrecord
# counter 95
# Processing file: ./2/frame/train/train1248.tfrecord
# counter 96
# Processing file: ./2/frame/train/train2114.tfrecord
# counter 97
# Processing file: ./2/frame/train/train0275.tfrecord
# counter 98
# Processing file: ./2/frame/train/train0012.tfrecord
# counter 99
# Processing file: ./2/frame/train/train1341.tfrecord
# counter 100
# Processing file: ./2/frame/train/train0189.tfrecord
# counter 101
# Processing file: ./2/frame/train/train0406.tfrecord
# counter 102
# Processing file: ./2/frame/train/train2766.tfrecord
# counter 103
# Processing file: ./2/frame/train/train1839.tfrecord
# counter 104
# Processing file: ./2/frame/train/train1309.tfrecord
# counter 105
# Processing file: ./2/frame/train/train3068.tfrecord
# counter 106
# Processing file: ./2/frame/train/train2899.tfrecord
# counter 107
# Processing file: ./2/frame/train/train1293.tfrecord
# counter 108
# Processing file: ./2/frame/train/train3394.tfrecord
# counter 109
# Processing file: ./2/frame/train/train2593.tfrecord
# counter 110
# Processing file: ./2/frame/train/train2903.tfrecord
# counter 111
# Processing file: ./2/frame/train/train0471.tfrecord
# counter 112
# Processing file: ./2/frame/train/train0124.tfrecord
# counter 113
# Processing file: ./2/frame/train/train3591.tfrecord
# counter 114
# Processing file: ./2/frame/train/train2758.tfrecord
# counter 115
# Processing file: ./2/frame/train/train1807.tfrecord
# counter 116
# Processing file: ./2/frame/train/train0065.tfrecord
# counter 117
# Processing file: ./2/frame/train/train0531.tfrecord
# counter 118
# Processing file: ./2/frame/train/train3231.tfrecord
# counter 119
# Processing file: ./2/frame/train/train3056.tfrecord
# counter 120
# Processing file: ./2/frame/train/train2402.tfrecord
# counter 121
# Processing file: ./2/frame/train/train3297.tfrecord
# counter 122
# Processing file: ./2/frame/train/train2238.tfrecord
# counter 123
# Processing file: ./2/frame/train/train0907.tfrecord
# counter 124
# Processing file: ./2/frame/train/train1973.tfrecord
# counter 125
# Processing file: ./2/frame/train/train1784.tfrecord
# counter 126
# Processing file: ./2/frame/train/train1972.tfrecord
# counter 127
# Processing file: ./2/frame/train/train2084.tfrecord
# counter 128
# Processing file: ./2/frame/train/train0182.tfrecord
# counter 129
# Processing file: ./2/frame/train/train2085.tfrecord
# counter 130
# Processing file: ./2/frame/train/train2940.tfrecord
# counter 131
# Processing file: ./2/frame/train/train0444.tfrecord
# counter 132
# Processing file: ./2/frame/train/train0377.tfrecord
# counter 133
# Processing file: ./2/frame/train/train1904.tfrecord
# counter 134
# Processing file: ./2/frame/train/train0393.tfrecord
# counter 135
# Processing file: ./2/frame/train/train2294.tfrecord
# counter 136
# Processing file: ./2/frame/train/train0209.tfrecord
# counter 137
# Processing file: ./2/frame/train/train0301.tfrecord
# counter 138
# Processing file: ./2/frame/train/train0241.tfrecord
# counter 139
# Processing file: ./2/frame/train/train1621.tfrecord
# counter 140
# Processing file: ./2/frame/train/train3014.tfrecord
# counter 141
# Processing file: ./2/frame/train/train1180.tfrecord
# counter 142
# Processing file: ./2/frame/train/train0971.tfrecord
# counter 143
# Processing file: ./2/frame/train/train3449.tfrecord
# counter 144
# Processing file: ./2/frame/train/train0786.tfrecord
# counter 145
# Processing file: ./2/frame/train/train1926.tfrecord
# counter 146
# Processing file: ./2/frame/train/train1178.tfrecord
# counter 147
# Processing file: ./2/frame/train/train0812.tfrecord
# counter 148
# Processing file: ./2/frame/train/train0676.tfrecord
# counter 149
# Processing file: ./2/frame/train/train3310.tfrecord
# counter 150
# Processing file: ./2/frame/train/train2224.tfrecord
# counter 151
# Processing file: ./2/frame/train/train2043.tfrecord
# counter 152
# Processing file: ./2/frame/train/train3036.tfrecord
# counter 153
# Processing file: ./2/frame/train/train1357.tfrecord
# counter 154
# Processing file: ./2/frame/train/train2630.tfrecord
# counter 155
# Processing file: ./2/frame/train/train3359.tfrecord
# counter 156
# Processing file: ./2/frame/train/train1691.tfrecord
# counter 157
# Processing file: ./2/frame/train/train2174.tfrecord
# counter 158
# Processing file: ./2/frame/train/train1412.tfrecord
# counter 159
# Processing file: ./2/frame/train/train1674.tfrecord
# counter 160
# Processing file: ./2/frame/train/train0741.tfrecord
# counter 161
# Processing file: ./2/frame/train/train2646.tfrecord
# counter 162
# Processing file: ./2/frame/train/train0925.tfrecord
# counter 163
# Processing file: ./2/frame/train/train2380.tfrecord
# counter 164
# Processing file: ./2/frame/train/train0600.tfrecord
# counter 165
# Processing file: ./2/frame/train/train3633.tfrecord
# counter 166
# Processing file: ./2/frame/train/train0133.tfrecord
# counter 167
# Processing file: ./2/frame/train/train2252.tfrecord
# counter 168
# Processing file: ./2/frame/train/train3135.tfrecord
# counter 169
# Processing file: ./2/frame/train/train1254.tfrecord
# counter 170
# Processing file: ./2/frame/train/train1255.tfrecord
# counter 171
# Processing file: ./2/frame/train/train0634.tfrecord
# counter 172
# Processing file: ./2/frame/train/train2732.tfrecord
# counter 173
# Processing file: ./2/frame/train/train3461.tfrecord
# counter 174
# Processing file: ./2/frame/train/train2093.tfrecord
# counter 175
# Processing file: ./2/frame/train/train2956.tfrecord
# counter 176
# Processing file: ./2/frame/train/train3428.tfrecord
# counter 177
# Processing file: ./2/frame/train/train1749.tfrecord
# counter 178
# Processing file: ./2/frame/train/train1387.tfrecord
# counter 179
# Processing file: ./2/frame/train/train3281.tfrecord
# counter 180
# Processing file: ./2/frame/train/train1825.tfrecord
# counter 181
# Processing file: ./2/frame/train/train3520.tfrecord
# counter 182
# Processing file: ./2/frame/train/train2672.tfrecord
# counter 183
# Processing file: ./2/frame/train/train0512.tfrecord
# counter 184
# Processing file: ./2/frame/train/train1173.tfrecord
# counter 185
# Processing file: ./2/frame/train/train1853.tfrecord
# counter 186
# Processing file: ./2/frame/train/train2968.tfrecord
# counter 187
# Processing file: ./2/frame/train/train0030.tfrecord
# counter 188
# Processing file: ./2/frame/train/train0703.tfrecord
# counter 189
# Processing file: ./2/frame/train/train3264.tfrecord
# counter 190
# Processing file: ./2/frame/train/train2522.tfrecord
# counter 191
# Processing file: ./2/frame/train/train2283.tfrecord
# counter 192
# Processing file: ./2/frame/train/train2920.tfrecord
# counter 193
# Processing file: ./2/frame/train/train2769.tfrecord
# counter 194
# Processing file: ./2/frame/train/train2494.tfrecord
# counter 195
# Processing file: ./2/frame/train/train1307.tfrecord
# counter 196
# Processing file: ./2/frame/train/train0500.tfrecord
# counter 197
# Processing file: ./2/frame/train/train0501.tfrecord
# counter 198
# Processing file: ./2/frame/train/train2334.tfrecord
# counter 199
# Processing file: ./2/frame/train/train3614.tfrecord
# counter 200
# Processing file: ./2/frame/train/train3127.tfrecord
# counter 201
# Processing file: ./2/frame/train/train2081.tfrecord
# counter 202
# Processing file: ./2/frame/train/train1808.tfrecord
# counter 203
# Processing file: ./2/frame/train/train0437.tfrecord
# counter 204
# Processing file: ./2/frame/train/train2933.tfrecord
# counter 205
# Processing file: ./2/frame/train/train2439.tfrecord
# counter 206
# Processing file: ./2/frame/train/train2616.tfrecord
# counter 207
# Processing file: ./2/frame/train/train0576.tfrecord
# counter 208
# Processing file: ./2/frame/train/train2124.tfrecord
# counter 209
# Processing file: ./2/frame/train/train2125.tfrecord
# counter 210
# Processing file: ./2/frame/train/train3545.tfrecord
# counter 211
# Processing file: ./2/frame/train/train2846.tfrecord
# counter 212
# Processing file: ./2/frame/train/train2847.tfrecord
# counter 213
# Processing file: ./2/frame/train/train2018.tfrecord
# counter 214
# Processing file: ./2/frame/train/train0378.tfrecord
# counter 215
# Processing file: ./2/frame/train/train1935.tfrecord
# counter 216
# Processing file: ./2/frame/train/train2051.tfrecord
# counter 217
# Processing file: ./2/frame/train/train0330.tfrecord
# counter 218
# Processing file: ./2/frame/train/train0156.tfrecord
# counter 219
# Processing file: ./2/frame/train/train1537.tfrecord
# counter 220
# Processing file: ./2/frame/train/train3302.tfrecord
# counter 221
# Processing file: ./2/frame/train/train1063.tfrecord
# counter 222
# Processing file: ./2/frame/train/train3164.tfrecord
# counter 223
# Processing file: ./2/frame/train/train2763.tfrecord
# counter 224
# Processing file: ./2/frame/train/train0664.tfrecord
# counter 225
# Processing file: ./2/frame/train/train3180.tfrecord
# counter 226
# Processing file: ./2/frame/train/train0028.tfrecord
# counter 227
# Processing file: ./2/frame/train/train0346.tfrecord
# counter 228
# Processing file: ./2/frame/train/train3446.tfrecord
# counter 229
# Processing file: ./2/frame/train/train0752.tfrecord
# counter 230
# Processing file: ./2/frame/train/train0753.tfrecord
# counter 231
# Processing file: ./2/frame/train/train3595.tfrecord
# counter 232
# Processing file: ./2/frame/train/train1998.tfrecord
# counter 233
# Processing file: ./2/frame/train/train2831.tfrecord
# counter 234
# Processing file: ./2/frame/train/train2209.tfrecord
# counter 235
# Processing file: ./2/frame/train/train1037.tfrecord
# counter 236
# Processing file: ./2/frame/train/train2737.tfrecord
# counter 237
# Processing file: ./2/frame/train/train2676.tfrecord
# counter 238
# Processing file: ./2/frame/train/train0770.tfrecord
# counter 239
# Processing file: ./2/frame/train/train0516.tfrecord
# counter 240
# Processing file: ./2/frame/train/train2323.tfrecord
# counter 241
# Processing file: ./2/frame/train/train2600.tfrecord
# counter 242
# Processing file: ./2/frame/train/train1367.tfrecord
# counter 243
# Processing file: ./2/frame/train/train0962.tfrecord
# counter 244
# Processing file: ./2/frame/train/train1192.tfrecord
# counter 245
# Processing file: ./2/frame/train/train1586.tfrecord
# counter 246
# Processing file: ./2/frame/train/train3413.tfrecord
# counter 247
# Processing file: ./2/frame/train/train3675.tfrecord
# counter 248
# Processing file: ./2/frame/train/train1040.tfrecord
# counter 249
# Processing file: ./2/frame/train/train2741.tfrecord
# counter 250
# Processing file: ./2/frame/train/train3641.tfrecord
# counter 251
# Processing file: ./2/frame/train/train2046.tfrecord
# counter 252
# Processing file: ./2/frame/train/train2047.tfrecord
# counter 253
# Processing file: ./2/frame/train/train3173.tfrecord
# counter 254
# Processing file: ./2/frame/train/train2581.tfrecord
# counter 255
# Processing file: ./2/frame/train/train3387.tfrecord
# counter 256
# Processing file: ./2/frame/train/train0554.tfrecord
# counter 257
# Processing file: ./2/frame/train/train2634.tfrecord
# counter 258
# Processing file: ./2/frame/train/train0267.tfrecord
# counter 259
# Processing file: ./2/frame/train/train0001.tfrecord
# counter 260
# Processing file: ./2/frame/train/train3583.tfrecord
# counter 261
# Processing file: ./2/frame/train/train1779.tfrecord
# counter 262
# Processing file: ./2/frame/train/train2827.tfrecord
# counter 263
# Processing file: ./2/frame/train/train1143.tfrecord
# counter 264
# Processing file: ./2/frame/train/train3511.tfrecord
# counter 265
# Processing file: ./2/frame/train/train2699.tfrecord
# counter 266
# Processing file: ./2/frame/train/train1557.tfrecord
# counter 267
# Processing file: ./2/frame/train/train1198.tfrecord
# counter 268
# Processing file: ./2/frame/train/train2256.tfrecord
# counter 269
# Processing file: ./2/frame/train/train1264.tfrecord
# counter 270
# Processing file: ./2/frame/train/train1638.tfrecord
# counter 271
# Processing file: ./2/frame/train/train2966.tfrecord
# counter 272
# Processing file: ./2/frame/train/train0258.tfrecord
# counter 273
# Processing file: ./2/frame/train/train2731.tfrecord
# counter 274
# Processing file: ./2/frame/train/train0853.tfrecord
# counter 275
# Processing file: ./2/frame/train/train1139.tfrecord
# counter 276
# Processing file: ./2/frame/train/train0196.tfrecord
# counter 277
# Processing file: ./2/frame/train/train1138.tfrecord
# counter 278
# Processing file: ./2/frame/train/train2638.tfrecord
# counter 279
# Processing file: ./2/frame/train/train0583.tfrecord
# counter 280
# Processing file: ./2/frame/train/train1384.tfrecord
# counter 281
# Processing file: ./2/frame/train/train3076.tfrecord
# counter 282
# Processing file: ./2/frame/train/train1269.tfrecord
# counter 283
# Processing file: ./2/frame/train/train2862.tfrecord
# counter 284
# Processing file: ./2/frame/train/train3000.tfrecord
# counter 285
# Processing file: ./2/frame/train/train3266.tfrecord
# counter 286
# Processing file: ./2/frame/train/train1635.tfrecord
# counter 287
# Processing file: ./2/frame/train/train1452.tfrecord
# counter 288
# Processing file: ./2/frame/train/train2135.tfrecord
# counter 289
# Processing file: ./2/frame/train/train2213.tfrecord
# counter 290
# Processing file: ./2/frame/train/train1774.tfrecord
# counter 291
# Processing file: ./2/frame/train/train3673.tfrecord
# counter 292
# Processing file: ./2/frame/train/train1221.tfrecord
# counter 293
# Processing file: ./2/frame/train/train3326.tfrecord
# counter 294
# Processing file: ./2/frame/train/train2923.tfrecord
# counter 295
# Processing file: ./2/frame/train/train0386.tfrecord
# counter 296
# Processing file: ./2/frame/train/train3048.tfrecord
# counter 297
# Processing file: ./2/frame/train/train2917.tfrecord
# counter 298
# Processing file: ./2/frame/train/train0229.tfrecord
# counter 299
# Processing file: ./2/frame/train/train3420.tfrecord
# counter 300
# Processing file: ./2/frame/train/train2227.tfrecord
# counter 301
# Processing file: ./2/frame/train/train0321.tfrecord
# counter 302
# Processing file: ./2/frame/train/train2226.tfrecord
# counter 303
# Processing file: ./2/frame/train/train0882.tfrecord
# counter 304
# Processing file: ./2/frame/train/train1215.tfrecord
# counter 305
# Processing file: ./2/frame/train/train3312.tfrecord
# counter 306
# Processing file: ./2/frame/train/train3252.tfrecord
# counter 307
# Processing file: ./2/frame/train/train0006.tfrecord
# counter 308
# Processing file: ./2/frame/train/train0858.tfrecord
# counter 309
# Processing file: ./2/frame/train/train1466.tfrecord
# counter 310
# Processing file: ./2/frame/train/train3042.tfrecord
# counter 311
# Processing file: ./2/frame/train/train0742.tfrecord
# counter 312
# Processing file: ./2/frame/train/train1880.tfrecord
# Skipping entire file due to corruption: ./2/frame/train/train1880.tfrecord: truncated record at 55479261' failed with Read less bytes than requested
# counter 313
# Processing file: ./2/frame/train/train1411.tfrecord
# counter 314
# Processing file: ./2/frame/train/train3516.tfrecord
# counter 315
# Processing file: ./2/frame/train/train0926.tfrecord
# counter 316
# Processing file: ./2/frame/train/train0866.tfrecord
# counter 317
# Processing file: ./2/frame/train/train0038.tfrecord
# counter 318
# Processing file: ./2/frame/train/train2563.tfrecord
# counter 319
# Processing file: ./2/frame/train/train2333.tfrecord
# counter 320
# Processing file: ./2/frame/train/train3535.tfrecord
# counter 321
# Processing file: ./2/frame/train/train1654.tfrecord
# counter 322
# Processing file: ./2/frame/train/train1208.tfrecord
# counter 323
# Processing file: ./2/frame/train/train3681.tfrecord
# counter 324
# Processing file: ./2/frame/train/train3680.tfrecord
# counter 325
# Processing file: ./2/frame/train/train1348.tfrecord
# counter 326
# Processing file: ./2/frame/train/train3474.tfrecord
# counter 327
# Processing file: ./2/frame/train/train2726.tfrecord
# counter 328
# Processing file: ./2/frame/train/train1597.tfrecord
# counter 329
# Processing file: ./2/frame/train/train0539.tfrecord
# counter 330
# Processing file: ./2/frame/train/train1159.tfrecord
# counter 331
# Processing file: ./2/frame/train/train3665.tfrecord
# counter 332
# Processing file: ./2/frame/train/train0431.tfrecord
# counter 333
# Processing file: ./2/frame/train/train0430.tfrecord
# counter 334
# Processing file: ./2/frame/train/train0656.tfrecord
# counter 335
# Processing file: ./2/frame/train/train1051.tfrecord
# counter 336
# Processing file: ./2/frame/train/train3331.tfrecord
# counter 337
# Processing file: ./2/frame/train/train1377.tfrecord
# counter 338
# Processing file: ./2/frame/train/train3085.tfrecord
# counter 339
# Processing file: ./2/frame/train/train0946.tfrecord
# counter 340
# Processing file: ./2/frame/train/train0119.tfrecord
# counter 341
# Processing file: ./2/frame/train/train3023.tfrecord
# counter 342
# Processing file: ./2/frame/train/train1343.tfrecord
# counter 343
# Processing file: ./2/frame/train/train2371.tfrecord
# counter 344
# Processing file: ./2/frame/train/train2370.tfrecord
# counter 345
# Processing file: ./2/frame/train/train3650.tfrecord
# counter 346
# Processing file: ./2/frame/train/train3651.tfrecord
# counter 347
# Processing file: ./2/frame/train/train2503.tfrecord
# counter 348
# Processing file: ./2/frame/train/train1291.tfrecord
# counter 349
# Processing file: ./2/frame/train/train2339.tfrecord
# counter 350
# Processing file: ./2/frame/train/train2900.tfrecord
# counter 351
# Processing file: ./2/frame/train/train0497.tfrecord
# counter 352
# Processing file: ./2/frame/train/train0806.tfrecord
# counter 353
# Processing file: ./2/frame/train/train1932.tfrecord
# counter 354
# Processing file: ./2/frame/train/train0126.tfrecord
# counter 355
# Processing file: ./2/frame/train/train1274.tfrecord
# counter 356
# Processing file: ./2/frame/train/train3373.tfrecord
# counter 357
# Processing file: ./2/frame/train/train1013.tfrecord
# counter 358
# Processing file: ./2/frame/train/train2712.tfrecord
# counter 359
# Processing file: ./2/frame/train/train3549.tfrecord
# counter 360
# Processing file: ./2/frame/train/train1768.tfrecord
# counter 361
# Processing file: ./2/frame/train/train3055.tfrecord

# %%
print('Number of videos in the new commercial dataset: ',len(filtered_vid_ids))
print ('Number of labels in the new commercial dataset: ', len (filtered_labels))
print('Length of visual features: ', len(filtered_rgb))
print('Length of audio features', len(filtered_audio))
print('Picking a youtube video id:',filtered_vid_ids[5])
# Out:
# Number of videos in the new commercial dataset:  474
# Number of labels in the new commercial dataset:  474
# Length of visual features:  2358
# Length of audio features 2358
# Picking a youtube video id: g65F

# %%
print('Number of videos in the new commercial dataset: ',len(non_filtered_vid_ids))
print ('Number of labels in the new commercial dataset: ', len (non_filtered_labels))
print('Length of visual features: ', len(non_filtered_rgb))
print('Length of audio features', len(non_filtered_audio))
print('Picking a youtube video id:',non_filtered_vid_ids[5])
# Out:
# Number of videos in the new commercial dataset:  21540
# Number of labels in the new commercial dataset:  21540
# Length of visual features:  21540
# Length of audio features 21540
# Picking a youtube video id: xFkY

# %%
print(filtered_vid_ids)
# Out:
# ['9ROF', 'LrUL', 'AEYN', 'TcYN', 'oAYN', 'g65F', '665F', 'Yv5F', 'zrlX', '6WlX', 'sZo2', 'bb1Q', 'jD1Q', 'ervz', 'tDvz', 'gXvz', 'ed4r', 'RYjX', 'Y1jX', 'GcjX', 'NhjX', 'pdqj', 'f2qj', 'TK2m', 'Nx2m', 'tW2m', 'QOKx', 'xnjl', 'ZZjl', '5kjl', 'HDjl', '67Qe', 'TFrN', 'SwZH', 'RUZH', 'oJnY', 'xHnY', 'uNnY', 'riqQ', 'vhmD', 'qTit', 'unoX', 'nNDz', 'xdDz', 'vmTj', 'bpTj', '3bTj', 'ZdTj', 'CDrW', 'EkCd', 'mw3X', 'u0G3', 'SOG3', 'ODD4', 'nqCJ', '055N', 'a9Mt', '0YMt', 'f1ez', 'Jzez', 'Iwez', 'ArlT', 'AvWZ', '7Upn', 'fopn', 'wxpn', 'hVpn', 'lipn', 'D0im', 'Kbim', 'jg2S', 'Qe2S', 'gBtC', 'Z8tC', 'RpHg', 'secF', 'R9cF', 'sIKd', 'AWKd', 'burE', 'IGrE', 'aHrE', '9Qla', 'H5Yl', 'BVYl', 'oMPC', '3xPC', 'qvb8', 'EufI', 'euBZ', 'mcBZ', '7TXm', 'EGTQ', 'pvoH', '6SoH', 'ZioH', 'ZMoH', 'FYIQ', 'GzIQ', 'xza4', 'D8a4', '9aa4', '5Dvc', 'Zgig', '3b14', 'Hk7A', 'bInI', 'jgnI', 'o9VG', '04Il', 'BWeE', 's2eE', 'gt27', 'pVcK', 'yScK', 'kxe6', 'naER', 'lEEN', 'TZEN', 'OzEN', 'c0Lo', 'Jkce', 'p0ce', 'Xwce', 'LMmK', 'qZmK', 'l6mK', 'AWN2', 'aEN2', 'M9El', 'CcIg', 's3Ig', '5OIg', 'xkeB', 'lLeB', 'gfeB', 'ydam', 'b0am', 'SGvN', 'aQvN', '6ldd', 'Eudd', 'gugI', 'l5SM', 'wZSM', 'PwDP', 'O5DP', 'LIDP', 'QFvh', 'cdXE', 'HhXE', '1eXE', 'aAUV', 'qlUV', 'uvUV', '6eu1', 'NN2U', 'X12U', 'DYPZ', '58PZ', '53PZ', 'EYPZ', 'BZhL', 'hthL', 'Prca', 'Xdca', 'M2ca', 'oX55', 'IS55', 'XoSE', 'irDj', '0rDj', 'ldDj', 'kGbd', 'uoiJ', 'jAMU', 'YhMU', 'U5MU', 'zoKg', 'alKg', 'b3oN', 'DMFZ', 'fiFZ', 'vlFY', 'GKFY', '2mc6', 'Tbc6', 'Hkc6', 'mSVA', 't8VA', 'x4VA', '29VA', 'cHhk', 'zchk', 'zihk', 'ZEhk', 'YFgf', 'f6ES', 'fZES', 'n1ES', 'Qge1', '5te1', 'CSWM', 'e2tc', 'Kftc', 'ZgpP', 'uv3N', 'AZ3N', 'UHta', 'hkng', 'Smng', '5jng', 'cD1y', 'QRJ2', 'AWv3', 'WG2l', 'vhBr', 'ldBa', 'D1Ba', 'p3l7', 'B8l7', '08l7', 'BYQQ', 'FVo5', 'CXo5', 'cc6L', 'sGKu', 'C8YJ', 'nAYJ', 'Kdup', 'jKSe', 'knSe', '63Se', 'T23Z', 'hDHV', '60HV', 'UJwx', 'sTwx', 'ufwx', '9Swx', '0uwx', 'dWwx', 'Sm05', 'GO4W', '96iq', 'o4s5', 'Qgs5', 'CSs5', 'U5s5', '1LV2', 'YgV2', 'rZV2', 'a2aE', '81aE', 'MKlv', 'KI0O', 'FHOQ', 'xGKZ', 'gjVg', 'X8Vg', 'HxOo', '4evf', '1xie', 'jMLO', '8fLO', '8W6s', '3sHJ', '77HJ', '9gDk', 'OUDk', 't8Dk', 'Uchd', '1aVt', 'WNVt', 'oXVt', 'ATQm', 'vlQm', 'QZjs', 'SzT4', 'V2T4', 'B2T5', 'GYGI', 'EEGI', '0mgg', 'dAFn', '4HFn', 'HgFn', 'w8Hf', 'SEfu', 'Xk1q', '5nrj', 'gGrj', 'ykrj', 'elZc', '1mSJ', 'VCSJ', 'rZSJ', 'qWkS', 'jfZs', 'RpaC', '3JaC', '3faC', 'HifK', 'M5fK', '3n59', 'CH59', 'xY59', 'Gl59', 'fy59', 'SEGo', 'uQGo', 'LzTP', 'jNTP', 'INJN', 'uXSj', 'klSj', 'qJLD', 'znP6', 'teP6', '7xP6', 'VJpG', 'iFpG', 'l5to', 'YQto', 'GqzK', 'NvzK', 'GC3d', 'bV3d', 'sM7r', 'CmqW', 'heqW', 'zqSn', 'YOSn', '0GHa', 'u8Ha', 'EhHa', 'NuHa', 'lYHb', 'npZl', 'mHPN', '2wPN', '4Ni6', 'Bfi6', 'H9i6', 'Q4et', 'xP5X', '4usB', 's4sB', 'RXRH', 'XQRH', 'tJzh', 'pwzh', 'KWtu', 'FkKy', 'LSKy', 'Lkuy', 'UUuy', 'YxV0', 'y7V0', 'FISd', 'w1Sd', '2PnV', 'F9nV', 'Uvsw', 'uPQI', 'SfQI', 't5jz', 'KVjz', 'Qijz', 'iJwu', '9Ewu', 'ahwu', '6UUk', '6CWy', '8EWy', 'AtWy', 'RQ0Q', '6CAx', 'iNAx', '5KAx', 'W6xA', '4uIB', '0VIB', '6VCM', 'TnCM', 'ukCM', 'UjtR', 'ueVd', 'VbVd', 'tLdR', 'WMdR', 'vx3k', 'QX3k', 'qMJ4', '8poo', 'r1tL', 'OY0C', '5r0C', '1Uag', 'BLag', 'qOn0', 'oon0', 'mon0', 'y6xO', 'yQxO', 'hAXe', 'faXe', 'T1Xe', 'XgXe', 'RlXe', 'HOwV', 'q1o6', 'sIn8', '3Tn8', 'tcaM', 'Y1aM', 'c0aM', 'yrPv', 'BTPv', 'VhPv', 'OkPv', 'yxPv', 'lzLN', 'OqAQ', 'SkAQ', 'QqAQ', 'C47x', '8J4c', 'f94c', '8Z4c', 'A9R8', 'K5zV', 'lZiR', 'gV7h', 'Pv7h', '3Yg6', 'qag6', 'evkK', 'Btq7', 'Sm1T', 'Guwn', '0Awn', 'Tjwn', 'W0pq', 'KWpq', 'eLpq', 'aIb5', 'y9b5', '6Pb5', 'mfWV', 'eRvP', 'OVMp', 'AeMo', 'gkMo', 'on62', 'Yj62', 'XMOx', '2hLT', 'RCUW', 'OCib', 'mrFk', 'HkFk', 'OgFk', 'yVcc', 'douI', 'ntuI', 'wM2z', 'xt2z', 'LC2z', '30qv', 'eiRU', 'zSRU', 'sd5p', 'MHXr']

# %%
print(non_filtered_vid_ids)
# Out:
# ['eAkY', '0RkY', 'bpkY', 'uNkY', 'nAkY', 'xFkY', 'YtkY', 'sGkY', 'EikY', 'gtkY', 'vtkY', 'FWkY', 'XBkY', '2PkY', 'C8kY', 'mvkY', 'H9kY', 'TIkY', 'tskY', 'p0kY', 'HwkY', 'PgkY', 'vKkY', 'GQkY', 'HikY', 'eakY', 'jJkY', 'oskY', 's7kY', 'wdkY', 'QjkY', 'aKkY', 'gNkY', 'WTkY', 'a3kY', 'DrkY', 'dzkY', 'f8kY', 'fgkY', '2kkY', 'bZkY', 'igkY', 'yIkY', 'bukY', 'SykY', 'K3kY', 's0kY', 'zUkY', '3ykY', 'l7kY', 'xQkY', '67kY', 'U2kY', 'sJkY', 'i8kY', '5RkY', 'N7kY', 'VnkY', 'cdkY', 'GskY', 'STkY', '49kY', 'tbkY', 'NyOF', 'NjOF', 'CQOF', 'wQOF', 'tEOF', 'qsOF', 'udOF', 'XdOF', 'r0OF', 'MSOF', 'VnOF', '3TOF', 'qSOF', 'daOF', 'BtOF', 'P8OF', 'U6OF', 'erOF', 'EjOF', 'UcOF', 'bUOF', 'xyOF', 'T3OF', 'TqOF', 'hYOF', 'l1OF', 'lwOF', 'dhOF', 'c6OF', 'eGOF', 'BxOF', 'IdOF', '2VOF', 'jNOF', '8bOF', 'scOF', 'zGOF', 'SNOF', 'cCOF', 'bwOF', 'MsOF', 'BhOF', 'Q5OF', '9mOF', 'MjOF', '1JOF', '3uOF', 'GGOF', 'fFOF', 'r9OF', 'fmOF', '2OOF', 'tQOF', 'gROF', 'oYOF', 'YKOF', 'rFOF', 'XxOF', 'AGgT', 'b6gT', 'bZgT', 'L7gT', 'HHgT', 'G7gT', 'p9gT', 'l5gT', 'ufgT', 'lpgT', 'y5gT', 'a3gT', 'OggT', 'qEgT', 'GSgT', 'TBgT', 'OsgT', 'o3gT', 'zigT', 'XIgT', 'MUgT', 'gFgT', 'F3gT', 'SqgT', '5QgT', 'vQgT', 'PmgT', 'W6gT', 'pngT', 'qFgT', 'orgT', 'K5gT', '2GgT', 'AogT', 'YFgT', 'hugT', 'QvgT', 'JBgT', 'j1gT', '1IgT', 'GLgT', 'sogT', 'aWgT', '5mgT', 'i5gT', 'E4gT', 'V8gT', 'xPgT', 'X4gT', 'wCgT', 'DMgT', 'MFgT', '2FgT', 'fxgT', 'msgT', 'OigT', 'slgT', 'z1Zi', 'CJZi', '2UZi', 'v3Zi', '3KZi', '7FZi', 'wOZi', 'DRZi', 'hXZi', 'iZZi', 'owZi', 'x0Zi', 'zuZi', 'AUZi', 'gRZi', 'v5Zi', 'cjZi', 'hkZi', 'cmZi', '3vZi', 'twZi', 'xJZi', 'RnZi', 'FAZi', 'h9Zi', 'S9Zi', '8dZi', 'itZi', 'LAZi', 'HhZi', 'nQZi', 'gEZi', 'G4Zi', 'mwZi', 'U0Zi', 'aVZi', 'nDZi', '8DZi', 'qoZi', 'Q3Zi', '79Zi', 'yzZi', 'v9Zi', 'DBZi', 'f3Zi', 'LfZi', 'JkZi', 'xzZi', 'ffZi', 'IFZi', 'D3Zi', 'whZi', 'cZZi', 'qDZi', 'LUZi', 'yrZi', 'gyZi', 'ymZi', '9QZi', 'aLZi', 'XBZi', 'eXZi', 'raZi', 'RZZi', '6eZi', 'hfZi', 'RWZi', 'haZi', 'WlZi', '8VZi', 'pqZi', 'q7Zi', 'dzZi', 'SkZi', 'TBZi', '9RZi', 'PpZi', '4cZi', 'hAZi', 'vOZi', 'sQZi', 'KBZi', '0jZi', 'kdZi', 'BtZi', '1oZi', 'obZi', 'kjZi', 'BNZi', 'EZZi', 'IlUL', 'UsUL', 'ksUL', 'CfUL', 'D9UL', 'oGUL', 'YUUL', '7JUL', 'zDUL', 'cdUL', 'r1UL', 'eQUL', 'hjUL', '6AUL', 'mqUL', 'UeUL', 'd4UL', '79UL', 'PKUL', '48UL', 'qeUL', 'jzUL', 'SXUL', 'wJUL', 'u6UL', 'bkUL', 'CKUL', 'XrUL', 'DIUL', 'OcUL', 'lTUL', 'DDUL', 'sQUL', 'NoUL', '7XUL', '7xUL', '1QUL', 'RhUL', 'tiUL', '7IUL', 'IAUL', 'YDUL', 'uTUL', 'gmUL', 'PiUL', 'q8UL', 'FZUL', 'AqUL', 'CNUL', 'nJUL', 'YbUL', 'ZKUL', 'p7UL', 'WjUL', 'PsUL', 'e1UL', 'S0UL', 'tsUL', 'X5UL', 'EeUL', 'EBUL', 'H0UL', 'slUL', 'KzUL', 'w0UL', 'QnUL', 'tNUL', 'EzYN', '5cYN', 'rtYN', 'Y2YN', 'BlYN', '9CYN', 'hOYN', 'iqYN', 'uHYN', 'bRYN', '1nYN', 'koYN', 'rsYN', 'w8YN', 'juYN', 'kBYN', 'xBYN', '3DYN', 'HlYN', 'XmYN', 'N9YN', 'QdYN', 'ozYN', '2rYN', 'TXYN', 'IQYN', 'xVYN', 'X6YN', 'W7YN', 'HyYN', 'BaYN', '2FYN', 'j3YN', 'tCYN', 'D2YN', '59YN', 'qCYN', 'dQYN', 'qEYN', 'AUYN', 'BsYN', '4PYN', 'GcYN', 'cKYN', '5XYN', 'rZYN', 'd6YN', '6SYN', 'v2ac', 'qRac', 'iAac', 'uhac', '1mac', 'Udac', 'QAac', 'K7ac', 'KKac', 'Alac', '9hac', 'FEac', 'jTac', 'x1ac', 'Lmac', 'Hyac', 'Hmac', 'iiac', 't4ac', 'jiac', 'Oqac', '4nac', 'Zkac', 'cxac', 'Yiac', 'dhac', '73ac', 'aSac', '3aac', 'Gdac', 'I6ac', 'fNac', 'Jrac', 'Smac', 'm1ac', '03ac', '5Iac', 'Umac', 'Vfac', '8Pac', 'jcac', 'dmac', 'qlac', 'nUac', 'hA5F', '185F', 'ic5F', 'kV5F', 'Ax5F', 'oB5F', 'pe5F', '5P5F', 'fB5F', 'ii5F', 'Xp5F', '5t5F', 'Om5F', '8s5F', 'qo5F', 'G25F', '0F5F', 'NO5F', 'Qe5F', 'bh5F', 'KF5F', 'wB5F', 'ua5F', 'Pw5F', 'on5F', '5j5F', 'zH5F', 'tI5F', 'uO5F', 'PA5F', 'yp5F', 'Ut5F', 'hH5F', '7k5F', 'MV5F', 'I15F', 'pr5F', '4q5F', 'X35F', 'zC5F', '0Q5F', 'xC5F', 'di5F', 'Xb5F', 'Ij5F', 'zV5F', 'MF5F', 'N35F', '8J5F', 'Hx5F', 'rK5F', 'T35F', '4R5F', 'Ka5F', 'll5F', 'qW5F', 'Sl5F', 'gz5F', 'oC5F', 'dA5F', 'B95F', 'Yq5F', 'Hj5F', 'Mw5F', 'vS5F', 'EM5F', 'tD5F', 'MT5F', 'Ci5F', 'oy5F', 'Io5F', 'vo5F', 'Kb5F', ...

# %% [markdown]
# - The video id wZ6U maps to wyHcL23Jvzs.

# %%
YouTubeVideo('DwnHaKYXbo0')

# %%
YouTubeVideo('XoxB1IPkG5Q')

# %%
# Randomly select 400 consistent pairs of RGB and audio features
if len(non_filtered_rgb) >= 500:
    selected_indices = random.sample(range(len(non_filtered_rgb)), 500)
    print(selected_indices)
    selected_rgb = [non_filtered_rgb[i] for i in selected_indices]
    selected_audio = [non_filtered_audio[i] for i in selected_indices]
else:
    print("Not enough non-filtered data to select 400 samples")

# Now selected_rgb and selected_audio contain 400 consistent random pairs of RGB and audio features
non_Commercial_Rgb+=(selected_rgb)
non_Commercial_Audio+=(selected_audio)
# Out:
# [13845, 12287, 2193, 4740, 14375, 15820, 879, 9470, 8599, 19373, 8808, 3136, 17673, 15128, 13893, 15094, 20474, 15118, 8841, 7329, 969, 9803, 528, 20464, 19845, 15292, 18697, 15761, 12337, 18706, 6525, 1352, 17816, 20314, 11181, 6495, 18765, 13106, 11500, 6746, 19641, 2279, 16444, 7071, 15927, 17458, 5092, 16502, 5006, 7181, 19970, 14966, 13302, 11853, 948, 14641, 3112, 2057, 18557, 19484, 19605, 21056, 11579, 1164, 5629, 11560, 15815, 15029, 21267, 805, 7709, 7103, 13530, 20529, 10048, 8686, 11286, 9402, 12325, 6024, 2950, 8559, 11497, 18822, 10404, 12539, 13791, 6110, 18978, 13954, 925, 8349, 2028, 8551, 14853, 14178, 4207, 15003, 2303, 5762, 15035, 11827, 8075, 4426, 4500, 18246, 2941, 645, 3861, 10888, 16434, 14576, 856, 10124, 17570, 9172, 18276, 10352, 13105, 16352, 3977, 18985, 14912, 9684, 1040, 14149, 4247, 5222, 9691, 19861, 7192, 5499, 9782, 16032, 8750, 6405, 7472, 3488, 20803, 15837, 20295, 4763, 2976, 19492, 7223, 12573, 3118, 5022, 4320, 11740, 7962, 8739, 8956, 17530, 581, 6106, 19102, 11606, 3560, 12241, 7347, 12911, 5338, 18456, 14777, 12614, 19835, 21301, 19032, 8072, 8463, 10974, 1920, 9668, 13731, 2674, 13939, 2577, 21509, 14541, 10494, 2915, 5356, 12594, 20760, 10260, 18452, 593, 8474, 6629, 14261, 6670, 6450, 14875, 21073, 12706, 119, 6575, 15325, 3086, 1972, 15252, 1296, 2835, 7133, 14294, 10255, 13825, 8866, 20244, 19057, 17123, 3830, 8488, 11289, 9, 4685, 469, 18693, 16081, 5959, 15867, 16235, 10802, 12354, 17895, 14821, 17534, 12966, 11976, 3308, 20029, 13900, 13202, 13733, 19538, 18720, 13284, 20122, 1921, 5471, 8367, 21001, 13030, 11698, 6281, 9364, 18238, 5226, 11203, 17230, 11188, 794, 20131, 3788, 19254, 4752, 7499, 18549, 1852, 18726, 8614, 10066, 15278, 1956, 20235, 661, 12701, 11466, 13215, 15930, 4717, 10553, 8393, 19871, 5223, 15552, 8415, 14718, 6487, 13257, 1786, 8206, 15330, 1257, 20834, 11119, 8444, 4463, 17177, 8272, 16582, 5693, 14659, 16929, 11134, 12020, 20157, 3181, 7352, 6998, 4652, 19534, 15891, 14256, 15637, 85, 16838, 7736, 8602, 9655, 7614, 15390, 15376, 4657, 9260, 859, 12309, 12817, 9407, 1046, 10552, 8624, 17574, 6994, 11131, 6656, 15642, 4518, 15389, 5862, 18459, 16302, 20510, 16603, 5126, 14174, 2836, 11091, 715, 5775, 1363, 5146, 2875, 17754, 16440, 14469, 16270, 10346, 14608, 6443, 9182, 3723, 5589, 5641, 4780, 6591, 12421, 13983, 8101, 16521, 12619, 14687, 12399, 5256, 16040, 12478, 4352, 14412, 11418, 13216, 3508, 698, 17755, 6415, 20374, 4229, 7542, 11113, 3213, 19199, 11072, 8932, 6732, 12891, 13187, 14972, 14085, 2393, 8324, 19411, 21197, 4923, 5043, 2569, 7291, 19028, 18298, 8562, 11742, 9118, 17241, 5613, 7036, 16363, 16833, 3595, 18674, 15391, 3252, 13625, 4474, 4600, 6421, 20885, 1725, 15020, 11843, 7907, 8304, 14494, 15117, 8666, 20782, 15428, 3462, 434, 19909, 20957, 10616, 15685, 16726, 21428, 21429, 8790, 2000, 8870, 2292, 14688, 5655, 19965, 19975, 10292, 15697, 11804, 10010, 9305, 90, 14259, 1479, 14487, 4815, 8104, 12514, 15715, 10528, 548, 10361, 15564, 1789, 785, 13576, 10385, 20274, 14859, 8153, 20110, 17324, 20743, 15566, 3981, 740, 4166, 5597, 432, 10307, 976, 601, 12174, 10042, 11732, 8740, 15125, 7790, 1717, 13092, 5371, 18292, 2417, 14243, 21107, 8242, 18633, 4697, 16531, 14658, 9342, 12098, 6791, 21188]

# %%
# The filtered audio-visual features of Television Advertisement is saved 
with open('filtered_rgb.pkl', 'wb') as f:
    pickle.dump(filtered_rgb, f)

with open('filtered_audio.pkl', 'wb') as f:
    pickle.dump(filtered_audio, f)

print('Filtered data features saved successfully.')
# Out:
# Filtered data features saved successfully.

# %%
print(len(non_Commercial_Rgb))
print(len(non_Commercial_Audio))
# Out:
# 1000
# 1000

# %%
# The Non-Commercial audio-visual features of Television Advertisement is saved 
with open('non_Commercial_Rgb.pkl', 'wb') as f:
    pickle.dump(non_Commercial_Rgb, f)

with open('non_Commercial_Audio.pkl', 'wb') as f:
    pickle.dump(non_Commercial_Audio, f)

print('Non-Commercial data features saved successfully.')
# Out:
# Non-Commercial data features saved successfully.
